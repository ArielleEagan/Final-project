# %%
import pandas as pd
from sklearn.metrics import mean_absolute_error
fpath = 'salaries_modified.csv'
fpath2 = 'salary.csv'

# %%
df_cleaned = pd.read_csv(fpath)
df = pd.read_csv(fpath2)
df
# Out:
#                 timestamp              company  level           title  \
# 0     2018-06-05 14:06:30             LinkedIn    5.0  Data Scientist
# 1     2018-06-08 09:49:25            Microsoft   64.0  Data Scientist
# 2     2018-06-10 19:39:35              Twitter    4.0  Data Scientist
# 3     2018-06-12 20:54:06               Google    6.0  Data Scientist
# 4     2018-06-17 11:39:38             Facebook    5.0  Data Scientist
# ...                   ...                  ...    ...             ...
# 1929  2021-08-15 22:31:26                Adobe    3.0  Data Scientist
# 1930  2021-08-16 16:17:19                  IBM    5.0  Data Scientist
# 1931  2021-08-16 17:08:58  Booz Allen Hamilton    5.0  Data Scientist
# 1932  2021-08-16 21:02:37                Xandr    1.0  Data Scientist
# 1933  2021-08-16 22:19:48             Facebook    4.0  Data Scientist
#
#       totalyearlycompensation  yearsofexperience  yearsatcompany  \
# ...

# %%
mean = df_cleaned.totalyearlycompensation.mean()

# %%
mean
# Out:
# 222.0005170630817

# %%
df['mean'] = mean
df.head()
# Out:
#              timestamp    company  level           title  \
# 0  2018-06-05 14:06:30   LinkedIn    5.0  Data Scientist
# 1  2018-06-08 09:49:25  Microsoft   64.0  Data Scientist
# 2  2018-06-10 19:39:35    Twitter    4.0  Data Scientist
# 3  2018-06-12 20:54:06     Google    6.0  Data Scientist
# 4  2018-06-17 11:39:38   Facebook    5.0  Data Scientist
#
#    totalyearlycompensation  yearsofexperience  yearsatcompany  \
# 0                    233.0                4.0             0.0
# 1                    218.0               11.0            11.0
# 2                    500.0                4.0             4.0
# 3                    685.0               22.0             2.0
# 4                    370.0                8.0             3.0
#
#    stockgrantvalue    bonus           city state country        mean
# 0            220.0     10.0  San Francisco    CA      US  222.000517
# 1             28.0     23.0        Seattle    WA      US  222.000517
# ...

# %%
y_true = df.totalyearlycompensation
y_pred = df["mean"]
# Out:
# pandas.core.series.Series

# %%
MAE = mean_absolute_error(y_true,y_pred)
MAE
# Out:
# 74.9416927158805

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import pandas as pd

df = pd.read_csv("salaries_modified.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#    Unnamed: 0            timestamp    company  level           title  \
# 0         745  2018-06-05 14:06:30   LinkedIn    5.0  Data Scientist
# 1         776  2018-06-08 09:49:25  Microsoft   64.0  Data Scientist
# 2         796  2018-06-10 19:39:35    Twitter    4.0  Data Scientist
# 3         822  2018-06-12 20:54:06     Google    6.0  Data Scientist
# 4         858  2018-06-17 11:39:38   Facebook    5.0  Data Scientist
#
#    totalyearlycompensation  yearsofexperience  yearsatcompany  \
# 0                    233.0                4.0             0.0
# 1                    218.0               11.0            11.0
# 2                    500.0                4.0             4.0
# 3                    685.0               22.0             2.0
# 4                    370.0                8.0             3.0
#
#    stockgrantvalue    bonus           city state country           city_state  \
# 0            220.0     10.0  San Francisco    CA      US  San Francisco%20CCA
# 1             28.0     23.0        Seattle    WA      US        Seattle%20CWA
# 2            280.0     20.0  San Francisco    CA      US  San Francisco%20CCA
# 3         296000.0  55000.0       Kirkland    WA      US       Kirkland%20CWA
# 4            140.0     40.0        Seattle    WA      US        Seattle%20CWA
#
#    distance_NY  distance_SF  distance_seattle
# 0      4680488          110           1297072
# 1      4606061      1296231               798
# 2      4680488          110           1297072
# 3      2566387      2714350           4479753
# 4      4606061      1296231               798

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1934 entries, 0 to 1933
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               1934 non-null   int64
#  1   timestamp                1934 non-null   object
#  2   company                  1934 non-null   object
#  3   level                    1934 non-null   float64
#  4   title                    1934 non-null   object
#  5   totalyearlycompensation  1934 non-null   float64
#  6   yearsofexperience        1934 non-null   float64
#  7   yearsatcompany           1934 non-null   float64
#  8   stockgrantvalue          1934 non-null   float64
#  9   bonus                    1934 non-null   float64
#  10  city                     1934 non-null   object
#  11  state                    1934 non-null   object
#  12  country                  1934 non-null   object
#  13  city_state               1934 non-null   object
#  14  distance_NY              1934 non-null   int64
#  15  distance_SF              1934 non-null   int64
#  16  distance_seattle         1934 non-null   int64
# dtypes: float64(6), int64(4), object(7)
# memory usage: 272.0+ KB

# %%
def clean_dist(dist):
    if dist == 'None':
        return None
    try:
        return int(dist)
    except:
        return None

# %%
for col in ['distance_NY', 'distance_SF', 'distance_seattle']:
    df[col]=df[col].apply(lambda x: clean_dist(x))

# %%
for col in ['distance_NY','distance_SF','distance_seattle']:
    df = df[df[col].notnull()].copy()

# %%
# Set features. This will also be used as your x values.
selected_features = df[['level', 'yearsofexperience', 'yearsatcompany', 'distance_NY', 'bonus', 'stockgrantvalue', 'distance_SF', 'distance_seattle']]

# %%
selected_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1934 entries, 0 to 1933
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   level              1934 non-null   float64
#  1   yearsofexperience  1934 non-null   float64
#  2   yearsatcompany     1934 non-null   float64
#  3   distance_NY        1934 non-null   int64
#  4   bonus              1934 non-null   float64
#  5   stockgrantvalue    1934 non-null   float64
#  6   distance_SF        1934 non-null   int64
#  7   distance_seattle   1934 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 136.0 KB

# %%
selected_features = selected_features[selected_features.notnull()].copy()
selected_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1934 entries, 0 to 1933
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   level              1934 non-null   float64
#  1   yearsofexperience  1934 non-null   float64
#  2   yearsatcompany     1934 non-null   float64
#  3   distance_NY        1934 non-null   int64
#  4   bonus              1934 non-null   float64
#  5   stockgrantvalue    1934 non-null   float64
#  6   distance_SF        1934 non-null   int64
#  7   distance_seattle   1934 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 136.0 KB

# %%
selected_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1934 entries, 0 to 1933
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   level              1934 non-null   float64
#  1   yearsofexperience  1934 non-null   float64
#  2   yearsatcompany     1934 non-null   float64
#  3   distance_NY        1934 non-null   int64
#  4   bonus              1934 non-null   float64
#  5   stockgrantvalue    1934 non-null   float64
#  6   distance_SF        1934 non-null   int64
#  7   distance_seattle   1934 non-null   int64
# dtypes: float64(5), int64(3)
# memory usage: 136.0 KB

# %%
import numpy as np
inf_df = selected_features.isin([np.inf, -np.inf])
len(inf_df)
# Out:
# 1934

# %%
selected_features.head()
# Out:
#    level  yearsofexperience  yearsatcompany  distance_NY    bonus  \
# 0    5.0                4.0             0.0      4680488     10.0
# 1   64.0               11.0            11.0      4606061     23.0
# 2    4.0                4.0             4.0      4680488     20.0
# 3    6.0               22.0             2.0      2566387  55000.0
# 4    5.0                8.0             3.0      4606061     40.0
#
#    stockgrantvalue  distance_SF  distance_seattle
# 0            220.0          110           1297072
# 1             28.0      1296231               798
# 2            280.0          110           1297072
# 3         296000.0      2714350           4479753
# 4            140.0      1296231               798

# %%
df.describe()
# Out:
#          Unnamed: 0        level  totalyearlycompensation  yearsofexperience  \
# count   1934.000000  1934.000000              1934.000000        1934.000000
# mean   33393.588935    14.643226               222.000517           5.050672
# std    17503.726027    49.932431               105.199972           4.055170
# min      745.000000     0.000000                16.000000           0.000000
# 25%    19355.250000     4.000000               152.000000           2.000000
# 50%    33569.500000     5.000000               200.000000           4.000000
# 75%    48975.750000     6.000000               260.000000           7.000000
# max    62610.000000   603.000000              1000.000000          34.000000
#
#        yearsatcompany  stockgrantvalue         bonus   distance_NY  \
# count     1934.000000      1934.000000   1934.000000  1.934000e+03
# mean         2.043873       211.790589     78.555843  3.473487e+06
# std          2.274708      6745.015178   1497.653081  1.832508e+06
# min          0.000000         0.000000      0.000000  1.000700e+04
# 25%          0.000000         0.000000      7.000000  1.929914e+06
# 50%          2.000000        30.000000     15.000000  4.606061e+06
# 75%          3.000000        63.750000     27.000000  4.680488e+06
# max         20.000000    296000.000000  55000.000000  4.796489e+06
#
#         distance_SF  distance_seattle
# count  1.934000e+03      1.934000e+03
# mean   1.623933e+06      1.953982e+06
# std    1.796548e+06      1.630193e+06
# min    1.100000e+02      7.980000e+02
# 25%    5.239400e+04      1.297072e+06
# 50%    1.296231e+06      1.348731e+06
# 75%    3.174687e+06      3.363231e+06
# max    4.977621e+06      5.305593e+06

# %%
X = selected_features
y = df.totalyearlycompensation
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1, test_size=0.2)

# %%
X.shape
# Out:
# (1934, 8)

# %%
y.shape
# Out:
# (1934,)

# %%
y.head
# Out:
# <bound method NDFrame.head of 0       233.0
# 1       218.0
# 2       500.0
# 3       685.0
# 4       370.0
#         ...
# 1929    250.0
# 1930    145.0
# 1931    110.0
# 1932    120.0
# 1933    233.0
# Name: totalyearlycompensation, Length: 1934, dtype: float64>

# %%
X.dtypes
# Out:
# level                float64
# yearsofexperience    float64
# yearsatcompany       float64
# distance_NY            int64
# bonus                float64
# stockgrantvalue      float64
# distance_SF            int64
# distance_seattle       int64
# dtype: object

# %%
sc_X = StandardScaler()
X_trainscaled=sc_X.fit_transform(X_train)
X_testscaled=sc_X.transform(X_test)

# %%
np.where(np.isnan(X_trainscaled))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
reg = MLPRegressor(hidden_layer_sizes=(200,100,50),activation="relu" ,
                   random_state=42, learning_rate='adaptive', max_iter=2000, solver='adam', early_stopping=True).fit(X_trainscaled, y_train)

# %%
parameter_space = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (100,)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'learning_rate': ['constant','adaptive'],
}

# %%
from sklearn.metrics import mean_absolute_error
y_pred=reg.predict(X_testscaled)
print("The Score with ", (mean_absolute_error(y_pred, y_test)))
# Out:
# The Score with  251.9634507563064

# %%
from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(reg, param_distributions = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (200,100,50)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.01, 0.001, .1],
    'learning_rate': ['constant','adaptive'],
    'max_iter': [1000,2000]},
    random_state=42
)

result = rs.fit(X_train, y_train)
# Out:
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_base.py:170: RuntimeWarning: overflow encountered in square
#   return ((y_true - y_pred) ** 2).mean() / 2
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: overflow encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\extmath.py:152: RuntimeWarning: invalid value encountered in matmul
#   ret = a @ b
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 673, in fit
#     return self._fit(X, y, incremental=False)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 399, in _fit
#     self._fit_stochastic(X, y, activations, deltas, coef_grads,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 586, in _fit_stochastic
#     self._update_no_improvement_count(early_stopping, X_val, y_val)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py", line 629, in _update_no_improvement_count
#     self.validation_scores_.append(self.score(X_val, y_val))
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\base.py", line 554, in score
#     return r2_score(y, y_pred, sample_weight=sample_weight)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 676, in r2_score
#     y_type, y_true, y_pred, multioutput = _check_reg_targets(
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\metrics\_regression.py", line 90, in _check_reg_targets
#     y_pred = check_array(y_pred, ensure_2d=False, dtype=dtype)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 63, in inner_f
#     return f(*args, **kwargs)
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 663, in check_array
#     _assert_all_finite(array,
#   File "C:\Users\richk\anaconda3\lib\site-packages\sklearn\utils\validation.py", line 103, in _assert_all_finite
#     raise ValueError(
# ValueError: Input contains NaN, infinity or a value too large for dtype('float64').
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# C:\Users\richk\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [-1.56060856e+02  4.82614594e-02             nan -1.20486761e+02
#  -6.80214610e-03 -5.83544129e-03             nan  4.83789078e-02
#  -8.74979085e-03 -8.75016507e-03]
#   warnings.warn(

# %%
best_params = result.best_params_

# %%
best_params
# Out:
# {'solver': 'adam',
#  'max_iter': 1000,
#  'learning_rate': 'constant',
#  'hidden_layer_sizes': (200, 100, 50),
#  'alpha': 0.1,
#  'activation': 'tanh'}

# %%
y_test_preds = rs.predict(X_test)
mean_absolute_error(y_test_preds, y_test)
# Out:
# 80.20064890502901

# %%
y_testscaled_preds = rs.predict(X_testscaled)
mean_absolute_error(y_testscaled_preds, y_testscaled)

from sklearn.model_selection import RandomizedSearchCV

rs = RandomizedSearchCV(reg, param_distributions = {
    'hidden_layer_sizes': [(50,50,50), (50,100,50), (200,100,50)],
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.01, 0.001, .1],
    'learning_rate': ['constant','adaptive'],
    'max_iter': [1000,2000]},
    random_state=42
)

result = rs.fit(X_trainscaled, y_trainscaled)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-55-e58d5e2f0929> in <module>
#       1 y_testscaled_preds = rs.predict(X_testscaled)
# ----> 2 mean_absolute_error(y_testscaled_preds, y_testscaled)
#       3
#       4 from sklearn.model_selection import RandomizedSearchCV
#       5
#
# NameError: name 'y_testscaled' is not defined

# %%
mean_absolute_error(df.totalyearlycompensation)

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)

# %%
actual_vals = [220, 100, 45, 350]
mean_vals = [150, 150, 150, 150]

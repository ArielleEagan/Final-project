# %%
import pandas as pd

# %%
df=pd.read_csv("distances.csv")

# %%
df
# Out:
#      Unnamed: 0                      city distance from NY
# 0             0       San Francisco%20CCA          4680488
# 1             1             Seattle%20CWA          4606061
# 2             2            San Jose%20CCA          4733129
# 3             3            Kirkland%20CWA          2566387
# 4             4            Bellevue%20CWA          4586918
# ..          ...                       ...              ...
# 161         161       Mountain View%20CMO          3419771
# 162         162  Annapolis Junction%20CMD           342073
# 163         163             Holmdel%20CNJ            76874
# 164         164            New City%20CNY            51652
# 165         165         West McLean%20CVA           382850
#
# [166 rows x 3 columns]

# %%
#Import dependencies
import pandas as pd
import requests

#API pull for latest salary info from www.levels.fyi
salaryData = requests.get('https://www.levels.fyi/js/salaryData.json').json()
salary_df = pd.DataFrame(salaryData)

#dropping columns that are not relevant to project
salary_df = salary_df.drop(['cityid', 'dmaid','rowNumber','otherdetails','tag', 'basesalary', 'stockgrantvalue', 'bonus', 'gender'], axis=1)

#converting to float to allow for summary stats
salary_df["totalyearlycompensation"] = pd.to_numeric(salary_df["totalyearlycompensation"])
salary_df["yearsofexperience"] = pd.to_numeric(salary_df["yearsofexperience"])
salary_df["yearsatcompany"] = pd.to_numeric(salary_df["yearsatcompany"])

#coverting timestamp from object to datetime
salary_df['timestamp'] =  pd.to_datetime(salary_df['timestamp'], infer_datetime_format=True)

# Create separate cols for city, state and country
def split_location(location):
    items = location.split(', ')
    city = items[0]
    state = items[1]
    
    if len(items)==2:
        country = 'US'
    elif len(items)==3:
        country = items[2].strip()
    elif len(items)==4:
        country = ', '.join([i.strip() for i in items[2:]])
    else:
        country = None
        print(location)
        
    return [city, state, country]

salary_df['loc_items'] = salary_df.location.apply(lambda x: split_location(x))
salary_df['city'] = salary_df.loc_items.apply(lambda x: x[0])
salary_df['state'] = salary_df.loc_items.apply(lambda x: x[1])
salary_df['country'] = salary_df.loc_items.apply(lambda x: x[2])

# dropping location column  
salary_df = salary_df.drop(['location','loc_items'], axis=1)

#isolating US data for further exploration
us_df = salary_df[salary_df.country=='US'].copy()

#isolating us data to data scientist titles
us_df = us_df[us_df.title=='Data Scientist'].copy()

# %%
us_df
# Out:
#                 timestamp              company              level  \
# 745   2018-06-05 14:06:30             LinkedIn             Senior
# 772   2018-06-08 00:29:47               Amazon                 L4
# 776   2018-06-08 09:49:25            Microsoft                 64
# 782   2018-06-08 17:55:09                 ebay                 26
# 796   2018-06-10 19:39:35              Twitter              Staff
# ...                   ...                  ...                ...
# 62569 2021-08-16 16:17:19                  IBM                 L5
# 62578 2021-08-16 17:08:58  Booz Allen Hamilton  Senior Consultant
# 62600 2021-08-16 21:02:37                Xandr                 L1
# 62610 2021-08-16 22:19:48             Facebook                 L4
# 62636 2021-08-17 07:55:47                 AT&T          Principal
#
#                 title  totalyearlycompensation  yearsofexperience  \
# 745    Data Scientist                    233.0                4.0
# 772    Data Scientist                    140.0                2.0
# 776    Data Scientist                    218.0               11.0
# 782    Data Scientist                    180.0               10.0
# 796    Data Scientist                    500.0                4.0
# ...               ...                      ...                ...
# 62569  Data Scientist                    145.0                6.0
# 62578  Data Scientist                    110.0                0.0
# 62600  Data Scientist                    120.0                1.0
# 62610  Data Scientist                    233.0                2.0
# 62636  Data Scientist                    175.0                9.0
#
#        yearsatcompany           city state country
# 745               0.0  San Francisco    CA      US
# 772               2.0        Seattle    WA      US
# 776              11.0        Seattle    WA      US
# 782               5.0       San Jose    CA      US
# 796               4.0  San Francisco    CA      US
# ...               ...            ...   ...     ...
# 62569             5.0       New City    NY      US
# 62578             0.0    West McLean    VA      US
# 62600             0.0       Portland    OR      US
# 62610             2.0     Menlo Park    CA      US
# 62636             7.0        Atlanta    GA      US
#
# [2227 rows x 10 columns]

# %%
us_df['city'] = us_df.city.apply(lambda x: x.strip())
us_df['state'] = us_df.state.apply(lambda x: x.strip())

# %%
us_df['city_state'] = us_df.apply(lambda row: row.city + '%20C' + row.state, axis=1)

# %%
us_df
# Out:
#                 timestamp              company              level  \
# 745   2018-06-05 14:06:30             LinkedIn             Senior
# 772   2018-06-08 00:29:47               Amazon                 L4
# 776   2018-06-08 09:49:25            Microsoft                 64
# 782   2018-06-08 17:55:09                 ebay                 26
# 796   2018-06-10 19:39:35              Twitter              Staff
# ...                   ...                  ...                ...
# 62569 2021-08-16 16:17:19                  IBM                 L5
# 62578 2021-08-16 17:08:58  Booz Allen Hamilton  Senior Consultant
# 62600 2021-08-16 21:02:37                Xandr                 L1
# 62610 2021-08-16 22:19:48             Facebook                 L4
# 62636 2021-08-17 07:55:47                 AT&T          Principal
#
#                 title  totalyearlycompensation  yearsofexperience  \
# 745    Data Scientist                    233.0                4.0
# 772    Data Scientist                    140.0                2.0
# 776    Data Scientist                    218.0               11.0
# 782    Data Scientist                    180.0               10.0
# 796    Data Scientist                    500.0                4.0
# ...               ...                      ...                ...
# 62569  Data Scientist                    145.0                6.0
# 62578  Data Scientist                    110.0                0.0
# 62600  Data Scientist                    120.0                1.0
# 62610  Data Scientist                    233.0                2.0
# 62636  Data Scientist                    175.0                9.0
#
#        yearsatcompany           city state country           city_state
# 745               0.0  San Francisco    CA      US  San Francisco%20CCA
# 772               2.0        Seattle    WA      US        Seattle%20CWA
# 776              11.0        Seattle    WA      US        Seattle%20CWA
# 782               5.0       San Jose    CA      US       San Jose%20CCA
# 796               4.0  San Francisco    CA      US  San Francisco%20CCA
# ...               ...            ...   ...     ...                  ...
# 62569             5.0       New City    NY      US       New City%20CNY
# 62578             0.0    West McLean    VA      US    West McLean%20CVA
# 62600             0.0       Portland    OR      US       Portland%20COR
# 62610             2.0     Menlo Park    CA      US     Menlo Park%20CCA
# 62636             7.0        Atlanta    GA      US        Atlanta%20CGA
#
# [2227 rows x 11 columns]

# %%
n=len(us_df)
n
# Out:
# 2227

# %%
z=[]
for i in range(n):
    z.append(0)
us_df['distance_NY']=z

# %%
d=[]
for idx, row in df.iterrows():
    for i, r in us_df.iterrows():
        if r['city_state']==row['city']:
            r['distance_NY']=row['distance from NY']

# %%
d=[]
for idx, row in us_df.iterrows():
    x=row['city_state']
    for i, r in df.iterrows():
        y=r['city']
        if x==y:
            d.append(r['distance from NY'])
print(d)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-b33ce7b1f5f1> in <module>
#       2 for idx, row in us_df.iterrows():
#       3     x=row['city_state']
# ----> 4     for i, r in df.iterrows():
#       5         y=r['city']
#       6         if x==y:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in iterrows(self)
#     892         klass = self._constructor_sliced
#     893         for k, v in zip(self.index, self.values):
# --> 894             s = klass(v, index=columns, name=k)
#     895             yield k, s
#     896
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     309                     data = data.copy()
#     310             else:
# --> 311                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     312
#     313                 data = SingleBlockManager(data, index, fastpath=True)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in sanitize_array(data, index, dtype, copy, raise_cast_failure)
#     662         else:
#     663             # we will try to copy be-definition here
# --> 664             subarr = _try_cast(data, dtype, copy, raise_cast_failure)
#     665
#     666     elif isinstance(data, ExtensionArray):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/internals/construction.py in _try_cast(arr, dtype, copy, raise_cast_failure)
#     773     # perf shortcut as this is the most common case
#     774     if isinstance(arr, np.ndarray):
# --> 775         if maybe_castable(arr) and not copy and dtype is None:
#     776             return arr
#     777
#
# KeyboardInterrupt:

# %%
us_df
# Out:
#                 timestamp              company              level  \
# 745   2018-06-05 14:06:30             LinkedIn             Senior
# 772   2018-06-08 00:29:47               Amazon                 L4
# 776   2018-06-08 09:49:25            Microsoft                 64
# 782   2018-06-08 17:55:09                 ebay                 26
# 796   2018-06-10 19:39:35              Twitter              Staff
# ...                   ...                  ...                ...
# 62569 2021-08-16 16:17:19                  IBM                 L5
# 62578 2021-08-16 17:08:58  Booz Allen Hamilton  Senior Consultant
# 62600 2021-08-16 21:02:37                Xandr                 L1
# 62610 2021-08-16 22:19:48             Facebook                 L4
# 62636 2021-08-17 07:55:47                 AT&T          Principal
#
#                 title  totalyearlycompensation  yearsofexperience  \
# 745    Data Scientist                    233.0                4.0
# 772    Data Scientist                    140.0                2.0
# 776    Data Scientist                    218.0               11.0
# 782    Data Scientist                    180.0               10.0
# 796    Data Scientist                    500.0                4.0
# ...               ...                      ...                ...
# 62569  Data Scientist                    145.0                6.0
# 62578  Data Scientist                    110.0                0.0
# 62600  Data Scientist                    120.0                1.0
# 62610  Data Scientist                    233.0                2.0
# 62636  Data Scientist                    175.0                9.0
#
#        yearsatcompany           city state country           city_state  \
# 745               0.0  San Francisco    CA      US  San Francisco%20CCA
# 772               2.0        Seattle    WA      US        Seattle%20CWA
# 776              11.0        Seattle    WA      US        Seattle%20CWA
# 782               5.0       San Jose    CA      US       San Jose%20CCA
# 796               4.0  San Francisco    CA      US  San Francisco%20CCA
# ...               ...            ...   ...     ...                  ...
# 62569             5.0       New City    NY      US       New City%20CNY
# 62578             0.0    West McLean    VA      US    West McLean%20CVA
# 62600             0.0       Portland    OR      US       Portland%20COR
# 62610             2.0     Menlo Park    CA      US     Menlo Park%20CCA
# 62636             7.0        Atlanta    GA      US        Atlanta%20CGA
#
#        distance_NY
# 745              0
# 772              0
# 776              0
# 782              0
# 796              0
# ...            ...
# 62569            0
# 62578            0
# 62600            0
# 62610            0
# 62636            0
#
# [2227 rows x 12 columns]
